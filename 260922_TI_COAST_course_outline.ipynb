# %% [markdown]
# # TI-COAST
#
# Machine Learning Course for Chemists
# 22 Sept 2026
#
# John Mommers
# Henk-Jan van Manen
# Eric van Sprang

# %% [markdown]
# ## Content
#
# - Brief recap previous course
# - Machine Learning Examples
#   - Example 1: Prediction of LC retention times
#   - Example 2: Prediction of
#   - Example 3: Prediction of Solubility parameters
#
# - Best practice discussion
#   - workflow; how to start your own project
#   - using LLMs (ChatGPT, Claude) to write code (tips!)
#   - how to help YOU with your ML project
#
# - GitHub TI-Coast (work in progress)
